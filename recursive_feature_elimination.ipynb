# %%
import pandas as pd

# %%
# Read data.csv

data_df = pd.read_csv('data.csv')
data_df.head()
# Out:
#    k_2_by  k_4_by  k_6_by  k_8_by  k_9_by  k_10_by  k_14_by  k_16_by  k_18_by  \
# 0     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 1     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 2     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 3     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 4     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
#
#    k_19_by  ...  e_324  e_326  e_329  e_330  e_332  e_334  e_343  person_id  \
# 0      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN          1
# 1      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN          2
# 2      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN          3
# 3      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN          4
# 4      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN          5
#
#    birth_year  death_year
# ...

# %%
data_df = data_df.dropna(subset=['birth_year'])
data_df.shape
# Out:
# (57915, 843)

# %%
# birth_year is y to predict, person_id is id, and the rest are X. Run recursive_feature_elimination to find the best features to predict birth_year.

from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

X = data_df.drop(columns=['birth_year', 'person_id'])

y = data_df['birth_year']

rfe = RFE(RandomForestRegressor(), n_features_to_select=5)
rfe.fit(X, y)

X.columns[rfe.support_]
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 y = data_df['birth_year']
#      10 rfe = RFE(RandomForestRegressor(), n_features_to_select=5)
# ---> 11 rfe.fit(X, y)
#      13 X.columns[rfe.support_]
#
# File c:\Users\sudos\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py:184, in RFE.fit(self, X, y)
#     172 def fit(self, X, y):
#     173     """Fit the RFE model and then the underlying estimator on the selected
#     174        features.
#     175
#    (...)
#     182         The target values.
#     183     """
# --> 184     return self._fit(X, y)
#
# ...
